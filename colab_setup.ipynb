# %% [markdown]
# # Setup dan Eksekusi FB Group Monitoring
#
# Notebook ini berisi langkah-langkah untuk melakukan setup dan menjalankan bot monitoring grup Facebook.

# %%
# 1. Clone repositori dan pindah ke direktori
# !git clone https://github.com/username/fb_group_monitoring_platform.git
# %cd fb_group_monitoring_platform

# 2. Instal dependensi
# !pip install -r requirements.txt
# !playwright install chromium

# %%
# 3. Membuat direktori data dan file cookies.json
import json
import os

os.makedirs('data', exist_ok=True)

# Ganti dengan cookies Anda
cookies = []

with open('data/cookies.json', 'w') as f:
    json.dump(cookies, f)
    
print("File data/cookies.json telah dibuat.")

# %%
# 4. Menjalankan skrip list grup
# !python3 src/list_groups.py
